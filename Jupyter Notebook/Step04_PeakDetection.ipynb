# %% [markdown]
# ### ECG R-peak Detection

# %%
import pandas as pd
import sys
import os
from pathlib import Path
# %matplotlib inline
notebook_path = Path().resolve()  
supp_dir = notebook_path.parent 
sys.path.append(str(supp_dir))
from Step04_PeakDetection.ECG_Calculation_basing_HeartPy import ECGAnalyzer
from config import BASE_DIR
import warnings
warnings.filterwarnings('ignore')

# %%
def load_participant_data(window_data_dir: str, participant_id: str) -> pd.DataFrame:
    """
    Load participant data from files

    Args:
        window_data_dir: Directory containing window data files
        participant_id: ID of participant to load

    Returns:
        DataFrame containing participant data
    """
    try:
        input_file = os.path.join(window_data_dir, f"{participant_id}_processed_GD.csv")
        if not os.path.exists(input_file):
            print(f"File not found: {input_file}")
            return pd.DataFrame()
        df = pd.read_csv(input_file)
        df = df.rename(columns={'trueHR': 'polarHR'})
        return df

    except Exception as e:
        print(f"Error loading data for participant {participant_id}: {str(e)}")
        return pd.DataFrame()
def load_filter_parameters(param_dir: str, participant_id: str) -> pd.DataFrame:
    """
    Load filter parameters from file

    Args:
        param_dir: Directory containing parameter files
        participant_id: ID of participant to load parameters for

    Returns:
        DataFrame containing filter parameters
    """
    param_file = os.path.join(param_dir, f"{participant_id}_filter_params.csv")
    if not os.path.exists(param_file):
        raise FileNotFoundError(f"Parameter file not found for participant {participant_id}")
    return pd.read_csv(param_file)

def main():

    window_data_dir = os.path.join(BASE_DIR, 'WindowData')
    param_dir = os.path.join('..', 'Step04_PeakDetection', 'filter_parameters')


    analyzer = ECGAnalyzer()
    participant_id = 'P02'
    print(f"\nProcessing participant {participant_id}...")
    try:
        # Load data
        df = load_participant_data(window_data_dir, participant_id)

        # Load filter parameters
        filter_params = load_filter_parameters(param_dir, participant_id)

        # Process data
        processed_df, stats = analyzer.process_dataframe(df, filter_params)
        from IPython.display import display
        display(processed_df)
    except Exception as e:
        print(f"Error processing participant {participant_id}: {str(e)}")

main()
# Out:
# Processing participant P02...
#      participant     session  windowNumber      startTime        endTime  \
# 0            P02  adaptation             1  1710812041683  1710812049683
# 1            P02  adaptation             2  1710812043683  1710812051683
# 2            P02  adaptation             3  1710812045683  1710812053683
# 3            P02  adaptation             4  1710812047683  1710812055683
# 4            P02  adaptation             5  1710812049683  1710812057683
# ...          ...         ...           ...            ...            ...
# 1685         P02     running          1686  1710815652075  1710815660075
# 1686         P02     running          1687  1710815654075  1710815662075
# 1687         P02     running          1688  1710815656075  1710815664075
# 1688         P02     running          1689  1710815658075  1710815666075
# 1689         P02     running          1690  1710815660075  1710815668075
#
#       polarHR                                          galaxyPPG  \
# 0      84.000  2001992.0;2003293.0;2004050.0;2001962.0;199873...
# 1      84.000  1978357.0;1973015.0;1971421.0;1971545.0;197190...
# 2      83.750  2112188.0;2109026.0;2106716.0;2103992.0;210150...
# 3      83.125  1899408.0;1891633.2836520742;1885323.648098129...
# 4      82.625  1824757.0;1826506.1619323846;1827771.248273361...
# ...       ...                                                ...
# 1685  160.125  2286883.0;2287897.0;2274666.0;2235365.0;223490...
# 1686  160.375  1997258.0;2009174.7875222818;2021754.914825221...
# 1689  95;208;284;331;341;326;326;348;326;196;83;110;...
#
#                                                polarACC  isPadded        gdHR  \
# 0     -871;31;430;-869;35;430;-871;33;431;-868;30;43...     False   83.601286
# 1     -867;34;434;-865;34;435;-868;33;437;-867;34;44...     False   82.491187
# 2     -887;55;394;-886;57;393;-884;56;392;-890;62;39...     False   81.419624
# 3     -897;53;284;-900;49;279;-908;47;272;-917;40;27...     False   81.355932
# 4     -928;24;312;-929;28;306;-929;26;304;-933;27;29...     False   80.504587
# ...                                                 ...       ...         ...
# 1685  20;20;59;34;4;122;-9;-41;126;-112;-87;77;-229;...     False  159.836066
# 1686  -252;-195;34;-143;-145;17;-71;-101;-5;-43;-32;...     False       160.0
# 1687  -2591;193;258;-2365;97;507;-2098;-12;776;-1919...     False   160.56338
# 1688  128;43;-49;154;48;-31;153;75;2;118;126;10;28;2...     False  160.216216
# 1689  -77;125;40;-9;124;-28;49;122;-106;123;132;-161...     False       160.0
#
#            gdIBI     gdSDNN    gdRMSSD  \
# 0     717.692308  23.514372  14.951159
# 1     727.350427  18.085559  16.317849
# 2     736.923077  12.456367  18.666948
# 3          737.5  13.283755   19.50356
# 4     745.299145  10.494042   14.39099
# ...          ...        ...        ...
# 1685  375.384615   5.352711   8.998425
# 1686       375.0   4.912818   7.487143
# 1687  373.684211   3.901979   6.783978
# 1688  374.493927   3.673592   6.013354
# 1689       375.0   4.912818   8.463379
#
#                                                 gdPeaks
# 0            21;112;203;292;382;474;570;668;764;859;954
# 1                33;123;215;311;408;505;599;695;790;884
# 2           50;147;244;338;434;529;623;719;815;914;1008
# 3                    78;174;269;363;458;555;654;748;845
# 4               102;197;294;392;487;584;680;778;875;974
# ...                                                 ...
# 1685  50;99;148;197;245;295;343;393;442;491;539;589;...
# 1686  33;82;132;181;230;278;328;376;425;474;522;570;...
# 1687  68;117;166;214;263;311;359;408;457;505;554;602...
# 1688  50;98;147;196;244;293;341;390;439;487;536;584;...
# 1689  31;80;128;177;226;274;323;371;420;469;518;567;...
#
# [1690 rows x 18 columns]

# %% [markdown]
# ### PPG HRV Calculation basing different denosing signal

# %%
import contextlib
import warnings
import pandas as pd
import sys
import os
from Step04_PeakDetection.PPG_Calculation_basing_HeartPy import PPGAnalyzer
from config import WINDOW_DIR, RESULTS_DIR, DENOISING_ALGORITHMS
warnings.filterwarnings('ignore')

# %%
def load_data(window_dir: str, results_dir: str, participant_id: str, method: str) -> pd.DataFrame:
    try:
        denoised_file = os.path.join(results_dir, method, f"{participant_id}_processed_GD_denoised.csv")
        ground_truth_file = os.path.join(window_dir, f"{participant_id}_processed_GD.csv")
        denoised_df = pd.read_csv(denoised_file)
        ground_truth_df = pd.read_csv(ground_truth_file)
        columns_to_drop = ['gdHR', 'gdIBI', 'gdSDNN', 'gdRMSSD', 'gdPeaks']
        denoised_df = denoised_df.drop(columns=[col for col in columns_to_drop if col in denoised_df.columns])
        denoised_df['denoisedGalaxy'] = denoised_df['denoisedGalaxy'].astype(str)
        denoised_df['denoisedE4'] = denoised_df['denoisedE4'].astype(str)
        df = pd.merge(
            denoised_df,
            ground_truth_df[['windowNumber', 'session', 'gdHR', 'gdIBI', 'gdSDNN', 'gdRMSSD', 'gdPeaks']],
            on=['windowNumber', 'session'],
            how='left'
        )
        return df
    except Exception:
        return pd.DataFrame()
def main():
    analyzer = PPGAnalyzer()
    files = [f for f in os.listdir(WINDOW_DIR) if f.endswith('_processed_GD.csv')]

    all_results_df = []

    for method in DENOISING_ALGORITHMS:
        all_results = {}
        for file in files:
            participant_id = file.split('_')[0]
            try:
                df = load_data(WINDOW_DIR, RESULTS_DIR, participant_id, method)
                if not df.empty:
                    results = analyzer.analyze_data(df)
                    if results:
                        all_results[participant_id] = results
            except Exception:
                pass
        
        # Summarize results and add algorithm method column
        summary = analyzer.summarize_results(all_results)
        df_result = pd.DataFrame.from_dict(summary, orient='index').reset_index().rename(columns={'index': 'Session'})
        df_result['Algorithm'] = method
        all_results_df.append(df_result)

    final_df = pd.concat(all_results_df, ignore_index=True)
    display(final_df)
    return final_df

if __name__ == "__main__":
    with open(os.devnull, 'w') as fnull, contextlib.redirect_stdout(fnull), contextlib.redirect_stderr(fnull):
        try:
            result_df = main()
        except Exception:
            pass
# Out:
#             Session                                           PolarH10  \
# 0          baseline  {'HR': {'mean': 78.46985620969106, 'std': 9.50...
# 1       tsst-speech  {'HR': {'mean': 88.14744295349925, 'std': 10.7...
# 2    screen-reading  {'HR': {'mean': 79.1731768305581, 'std': 9.640...
# 3         ssst-sing  {'HR': {'mean': 94.6424450357511, 'std': 13.56...
# 4   keyboard-typing  {'HR': {'mean': 78.69119712035058, 'std': 7.60...
# 5     mobile-typing  {'HR': {'mean': 76.94642636622824, 'std': 7.00...
# 6          standing  {'HR': {'mean': 88.47458964329881, 'std': 11.3...
# 7           walking  {'HR': {'mean': 100.72228262710527, 'std': 9.9...
# 8           jogging  {'HR': {'mean': 133.77740092825465, 'std': 17....
# 9           running  {'HR': {'mean': 154.19433401272335, 'std': 17....
# 10         baseline  {'HR': {'mean': 78.46985620969106, 'std': 9.50...
# 11      tsst-speech  {'HR': {'mean': 88.14744295349925, 'std': 10.7...
# 12   screen-reading  {'HR': {'mean': 79.1731768305581, 'std': 9.640...
# 13        ssst-sing  {'HR': {'mean': 94.6424450357511, 'std': 13.56...
# 14  keyboard-typing  {'HR': {'mean': 78.69119712035058, 'std': 7.60...
# 15    mobile-typing  {'HR': {'mean': 76.94642636622824, 'std': 7.00...
# 16         standing  {'HR': {'mean': 88.47458964329881, 'std': 11.3...
# 17          walking  {'HR': {'mean': 100.72228262710527, 'std': 9.9...
# 18          jogging  {'HR': {'mean': 133.77740092825465, 'std': 17....
# 19          running  {'HR': {'mean': 154.19433401272335, 'std': 17....
# 20         baseline  {'HR': {'mean': 78.46985620969106, 'std': 9.50...
# 21      tsst-speech  {'HR': {'mean': 88.14744295349925, 'std': 10.7...
# 22   screen-reading  {'HR': {'mean': 79.1731768305581, 'std': 9.640...
# 23        ssst-sing  {'HR': {'mean': 94.6424450357511, 'std': 13.56...
# 24  keyboard-typing  {'HR': {'mean': 78.69119712035058, 'std': 7.60...
# 25    mobile-typing  {'HR': {'mean': 76.94642636622824, 'std': 7.00...
# 26         standing  {'HR': {'mean': 88.47458964329881, 'std': 11.3...
# 27          walking  {'HR': {'mean': 100.72228262710527, 'std': 9.9...
# 28          jogging  {'HR': {'mean': 133.77740092825465, 'std': 17....
# 29          running  {'HR': {'mean': 154.19433401272335, 'std': 17....
# 30         baseline  {'HR': {'mean': 78.46985620969106, 'std': 9.50...
# 31      tsst-speech  {'HR': {'mean': 88.14744295349925, 'std': 10.7...
# 32   screen-reading  {'HR': {'mean': 79.1731768305581, 'std': 9.640...
# 33        ssst-sing  {'HR': {'mean': 94.6424450357511, 'std': 13.56...
# 34  keyboard-typing  {'HR': {'mean': 78.69119712035058, 'std': 7.60...
# 35    mobile-typing  {'HR': {'mean': 76.94642636622824, 'std': 7.00...
# 36         standing  {'HR': {'mean': 88.47458964329881, 'std': 11.3...
# 37          walking  {'HR': {'mean': 100.72228262710527, 'std': 9.9...
# 38          jogging  {'HR': {'mean': 133.77740092825465, 'std': 17....
# 39          running  {'HR': {'mean': 154.19433401272335, 'std': 17....
#
#                                                Galaxy  \
# 0   {'HR': {'mean': 77.12840840510002, 'std': 10.8...
# 1   {'HR': {'mean': 84.33750345746812, 'std': 9.77...
# 2   {'HR': {'mean': 78.12151860502172, 'std': 10.5...
# 3   {'HR': {'mean': 89.59457470358316, 'std': 13.6...
# 4   {'HR': {'mean': 79.12577602178115, 'std': 7.71...
# 5   {'HR': {'mean': 76.28737867896221, 'std': 8.17...
# 6   {'HR': {'mean': 86.35448411398728, 'std': 11.7...
# 7   {'HR': {'mean': 97.62390251136871, 'std': 12.1...
# 8   {'HR': {'mean': 98.28599628452845, 'std': 22.4...
# 9   {'HR': {'mean': 95.17141649140083, 'std': 22.4...
# 10  {'HR': {'mean': 89.82649999609288, 'std': 20.3...
# 11  {'HR': {'mean': 76.30375365813762, 'std': 15.3...
# 12  {'HR': {'mean': 89.16301413592426, 'std': 21.8...
# 13  {'HR': {'mean': 79.33651185883642, 'std': 18.4...
# 14  {'HR': {'mean': 70.3550866444397, 'std': 11.92...
# 15  {'HR': {'mean': 76.42840593192014, 'std': 13.7...
# 16  {'HR': {'mean': 87.33612469197985, 'std': 17.1...
# 17  {'HR': {'mean': 72.3132960236309, 'std': 16.50...
# 18  {'HR': {'mean': 106.35215105226017, 'std': 22....
# 19  {'HR': {'mean': 98.59525778411124, 'std': 22.3...
# 20  {'HR': {'mean': 77.36449565144044, 'std': 10.1...
# 21  {'HR': {'mean': 69.14693651599029, 'std': 15.2...
# 22  {'HR': {'mean': 76.41682213925301, 'std': 11.5...
# 23  {'HR': {'mean': 72.14194839965762, 'std': 19.9...
# 24  {'HR': {'mean': 60.61149742111007, 'std': 10.0...
# 25  {'HR': {'mean': 69.69858209178668, 'std': 10.0...
# 26  {'HR': {'mean': 81.16293648056222, 'std': 15.4...
# 27  {'HR': {'mean': 63.807722471529985, 'std': 14....
# 28  {'HR': {'mean': 84.634042346006, 'std': 18.275...
# 29  {'HR': {'mean': 84.20979503939748, 'std': 14.6...
# 30  {'HR': {'mean': 77.34860932099616, 'std': 10.7...
# 31  {'HR': {'mean': 69.97409107109183, 'std': 16.9...
# 32  {'HR': {'mean': 76.55479742728666, 'std': 12.1...
# 33  {'HR': {'mean': 73.11129852683625, 'std': 22.9...
# 34  {'HR': {'mean': 59.39426350997185, 'std': 11.7...
# 35  {'HR': {'mean': 70.18216216316247, 'std': 10.9...
# 36  {'HR': {'mean': 82.36357299350331, 'std': 16.3...
# 37  {'HR': {'mean': 67.9912002319241, 'std': 17.62...
# 38  {'HR': {'mean': 100.06037557476841, 'std': 29....
# 39  {'HR': {'mean': 97.63513766585127, 'std': 26.9...
#
#                                                    E4 Algorithm
# 0   {'HR': {'mean': 79.10689006264732, 'std': 10.2...    Wiener
# 1   {'HR': {'mean': 87.02738488583806, 'std': 10.1...    Wiener
# 2   {'HR': {'mean': 81.62596720309631, 'std': 12.0...    Wiener
# 3   {'HR': {'mean': 92.34616212881556, 'std': 12.9...    Wiener
# 4   {'HR': {'mean': 82.77621653467031, 'std': 8.38...    Wiener
# 5   {'HR': {'mean': 77.68628143492326, 'std': 8.01...    Wiener
# 6   {'HR': {'mean': 88.19815470970732, 'std': 11.2...    Wiener
# 7   {'HR': {'mean': 108.26435910653103, 'std': 19....    Wiener
# 8   {'HR': {'mean': 97.87610842710814, 'std': 22.6...    Wiener
# 9   {'HR': {'mean': 99.29452775483524, 'std': 21.0...    Wiener
# 10  {'HR': {'mean': 102.72920236062066, 'std': 25....      IMAT
# 11  {'HR': {'mean': 88.82952825336017, 'std': 12.9...      IMAT
# 12  {'HR': {'mean': 100.88765876834496, 'std': 25....      IMAT
# 13  {'HR': {'mean': 95.10281056367853, 'std': 16.7...      IMAT
# 14  {'HR': {'mean': 86.69860084947953, 'std': 13.8...      IMAT
# 15  {'HR': {'mean': 92.96318054020115, 'std': 19.3...      IMAT
# 16  {'HR': {'mean': 95.93502396282852, 'std': 17.6...      IMAT
# 17  {'HR': {'mean': 88.24312069694017, 'std': 20.0...      IMAT
# 18  {'HR': {'mean': 110.49134710035027, 'std': 20....      IMAT
# 19  {'HR': {'mean': 107.13937653897047, 'std': 20....      IMAT
# 20  {'HR': {'mean': 75.99879189375335, 'std': 14.0...    Kalman
# 21  {'HR': {'mean': 80.4631952226727, 'std': 11.64...    Kalman
# 22  {'HR': {'mean': 77.00558905658546, 'std': 12.9...    Kalman
# 23  {'HR': {'mean': 86.10265313093105, 'std': 14.9...    Kalman
# 24  {'HR': {'mean': 75.24736742424743, 'std': 10.6...    Kalman
# 25  {'HR': {'mean': 73.55408521510685, 'std': 9.84...    Kalman
# 26  {'HR': {'mean': 85.57597425622023, 'std': 13.0...    Kalman
# 27  {'HR': {'mean': 80.97158262554223, 'std': 18.3...    Kalman
# 28  {'HR': {'mean': 93.24422600054923, 'std': 20.6...    Kalman
# 29  {'HR': {'mean': 95.28739377395401, 'std': 17.8...    Kalman
# 30  {'HR': {'mean': 77.87864514463051, 'std': 11.4...       SVD
# 31  {'HR': {'mean': 80.00005344047513, 'std': 13.2...       SVD
# 32  {'HR': {'mean': 77.75358410330145, 'std': 12.6...       SVD
# 33  {'HR': {'mean': 87.1943410940936, 'std': 17.38...       SVD
# 34  {'HR': {'mean': 71.72967984636416, 'std': 12.7...       SVD
# 35  {'HR': {'mean': 74.05196749975131, 'std': 9.82...       SVD
# 36  {'HR': {'mean': 85.55857805079582, 'std': 14.3...       SVD
# 37  {'HR': {'mean': 83.781066479486, 'std': 22.998...       SVD
# 38  {'HR': {'mean': 99.60161540391958, 'std': 28.4...       SVD
# 39  {'HR': {'mean': 102.65571035608907, 'std': 27....       SVD

# %%
from Step04_PeakDetection.raw_ppg_heartpy import rawPPGHeartPy
analyzer = rawPPGHeartPy()

# %% [markdown]
# #### Comparison Across Activities and Devices Using HeartPy Algorithms without Denoising

# %%
pd.read_csv('/home/iclab/GalaxyPPG/results/Denoised_Result/heartpy_raw_comparison.csv')
# Out:
#           Activity  PolarH10_HR  PolarH10_IBI  PolarH10_SDNN  PolarH10_RMSSD  \
# 0         baseline        78.47        775.09          40.86           41.63
# 1      tsst-speech        88.15        690.68          48.38           47.55
# 2   screen-reading        79.17        769.01          37.58           38.81
# 3        ssst-sing        94.64        647.14          42.64           44.42
# 4  keyboard-typing        78.69        770.11          30.12           33.80
# 5    mobile-typing        76.95        786.31          34.51           39.30
# 6         standing        88.47        689.74          36.29           34.33
# 7          walking       100.72        601.97          28.55           33.88
# 8          jogging       133.78        456.90          45.76           60.89
# 9          running       154.19        394.36          51.60           69.15
#
#    Galaxy_HR  Galaxy_IBI  Galaxy_SDNN  Galaxy_RMSSD  Galaxy_PMR   E4_HR  \
# 0      75.89      810.40       136.25        185.79       92.08   78.64
# 1      69.53      908.85       295.60        402.85       76.26   82.05
# 2      74.76      827.48       169.93        234.10       89.49   78.42
# 3      74.26      879.93       286.29        391.08       74.62   88.46
# 4      63.57      977.16       360.82        498.74       74.14   78.99
# 5      68.56      898.30       280.69        399.25       83.08   76.25
# 6      82.66      759.30       165.48        222.31       89.28   87.35
# 7      69.72      909.78       236.04        314.21       67.11   88.49
# 8      98.54      642.75       201.65        273.08       71.44  101.21
# 9      97.38      645.18       193.36        259.65       63.04  104.89
#
#    E4_IBI  E4_SDNN  E4_RMSSD  E4_PMR
# 0  781.07   103.83    137.15   96.03
# 1  748.66   190.42    259.70   88.09
# 2  782.87   111.63    149.93   94.56
# 3  699.66   172.98    238.24   88.99
# 4  780.04   270.26    372.76   87.01
# 5  801.31   210.23    299.69   90.94
# 6  703.82   115.25    151.67   93.05
# 7  713.13   230.74    320.05   80.70
# 8  624.20   169.60    226.27   73.31
# 9  599.62   154.59    203.76   67.45

# %% [markdown]
# #### Comparison Across Activities and Devices Using HeartPy Algorithms with Wiener Denoising

# %%
session_path = os.path.join(RESULTS_DIR,'session_analysis','Wiener', 'complete_analysis_results.csv')
%%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sys.path.append(os.path.abspath('..'))
from Step04_PeakDetection.hand_placement_analyzer import HandPlacementMAEAnalyzer
# Create an instance of the analyzer
analyzer = HandPlacementMAEAnalyzer()
# Run the analysis (this may take some time as it processes all participants)
print("Starting hand placement analysis...")
analyzer.run_analysis()
print("Analysis complete!")
# Out:
# Left hand users: 12 participants
# Right hand users: 12 participants
# Starting hand placement analysis...
# Processing participant: P01
# Warning: No processed ground truth data found for P01
# Processing participant: P02
# Processing participant: P03
# Processing participant: P04
# Processing participant: P05
# Processing participant: P06
# Processing participant: P07
# Processing participant: P08
# Processing participant: P09
# Processing participant: P10
# Processing participant: P11
# Processing participant: P12
# Processing participant: P13
# Processing participant: P14
# Processing participant: P15
# Processing participant: P16
# Processing participant: P17
# Processing participant: P18
# Processing participant: P19
# Processing participant: P20
# Processing participant: P21
# Processing participant: P22
# Processing participant: P23
# Processing participant: P24
# Analysis complete!

# %%
session_path = os.path.join(analyzer.output_dir, 'hand_placement_paired_ttest.csv')
pd.read_csv(session_path)
# Out:
#                                             Analysis  Number_of_Participants  \
# 0  Paired t-test for Left vs Right hand placement...                      23
#
#    Left_Hand_Mean_HR_MAE  Left_Hand_StdDev  Right_Hand_Mean_HR_MAE  \
# 0              15.877552          4.752523               15.263297
#
#    Right_Hand_StdDev  t_statistic   p_value  Significant
# 0           5.302049     0.458813  0.650869        False

# %%
session_path = os.path.join(analyzer.output_dir, 'participant_hand_placement_means.csv')
pd.read_csv(session_path)
# Out:
#    Participant GalaxyHandPlacement  Left_Mean_HR_MAE  Right_Mean_HR_MAE  \
# 0          P02                   R          9.073191          14.666288
# 1          P03                   L         16.104248          14.960986
# 2          P04                   R         13.492665          22.127952
# 3          P05                   L         20.589910          17.510965
# 4          P06                   R         12.748540           9.750388
# 5          P07                   L         15.700854           8.632446
# 6          P08                   R          7.630730           6.860087
# 7          P09                   L         14.261407          13.642176
# 8          P10                   R         16.203276          27.885493
# 9          P11                   L         20.991465          17.626577
# 10         P12                   R         13.219783          20.769856
# 11         P13                   L         24.100333          18.779862
# 12         P14                   R         11.664948          12.598963
# 13         P15                   L         19.309358          13.715458
# 14         P16                   R         12.217387          25.170356
# 15         P17                   L         16.306688           9.104635
# 16         P18                   R         14.890261           7.332833
# 17         P19                   L         20.258119          14.895592
# 18         P20                   R         10.659733          14.443532
# 19         P21                   L         19.077103          11.844251
# 20         P22                   R         19.025798          14.307193
# 21         P23                   L         27.069096          19.366204
# 22         P24                   R         10.588803          15.063740
#
#     Left_Count  Right_Count  Difference Better_Hand
# 0          708          708   -5.593097        Left
# 1          714          714    1.143261       Right
# 2          709          708   -8.635287        Left
# 3          697          697    3.078945       Right
# 4          711          711    2.998152       Right
# 5          698          698    7.068409       Right
# 6          698          698    0.770643       Right
# 7          695          695    0.619231       Right
# 8          703          703  -11.682217        Left
# 9          702          702    3.364888       Right
# 10         707          707   -7.550073        Left
# 11         704          704    5.320471       Right
# 12         704          704   -0.934015        Left
# 13         730          730    5.593900       Right
# 14         693          693  -12.952969        Left
# 15         701          701    7.202054       Right
# 16         712          712    7.557427       Right
# 17         689          689    5.362527       Right
# 18         709          709   -3.783799        Left
# 19         703          703    7.232852       Right
# 20         705          705    4.718605       Right
# 21         697          697    7.702892       Right
# 22         700          700   -4.474937        Left
